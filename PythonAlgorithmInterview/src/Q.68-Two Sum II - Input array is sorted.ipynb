# %% [markdown]
# # 두 수의 합2 | 난이도 🌟
# ### 문제 출처 - 리트 코드 [167번 문제 Two Sum II ](https://leetcode.com/problems/two-sum-ii-input-array-is-sorted)

# %%
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        
        i, j = 0, len(numbers)-1
        while i < j:
            if numbers[i] + numbers[j] == target:
                return [i+1,j+1]
            if numbers[i] + numbers[j] > target:
                j -= 1
            else:
                i += 1
