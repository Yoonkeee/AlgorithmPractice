# %% [markdown]
# # 주식을 사고팔기 가장 좋은 시점 II | 난이도 🌟
# ### 문제 출처 - 리트 코드 [122번 문제 Best Time to Buy and Sell Stock II](https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii)

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        return sum(max(0, prices[i+1] - prices[i]) for i in range(len(prices)-1))
