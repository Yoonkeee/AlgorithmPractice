# %% [markdown]
# 연속하는 자연수 두 개 이상을 곱해서 만들 수 있는 자연수를 크기 순으로 나열한 수열이 있습니다.
# 다음은 수열의 예시입니다.
# - 2, 6, 12, 20, 24, 30, 42, 56, 60, 72, 90, 110, 120, 132, 156, 182, ...
# 예를 들어 2는 두 연속하는 자연수 1, 2를 곱해서 만들 수 있습니다.
# 마찬가지로 6=2x3 또는 6=1x2x3이며, 20=4x5, 60=3x4x5와 같이 연속하는 자연수를 두 개
#
# i!/i-2! => 2*1=2!/0!, 3*2=3!/1!, 4*3=4!/2!, 5!/3!, 6!/4!, ... , n!/n-2!  , n>=2
# i!/i-3! => 3*2*1=3!/0!, 4*3*2=4!/1!, 5*4*3=5!/2!, 6*5*4=6!/3!, ... , n!/n-3!  , n>=3
# i!/i-4! => 4*3*2*1=4!/0!, 5*4*3*2=5!/1!, 6*5*4*3=6!/2!, ... , n!/n-4!  , n>=4
# ...

# %%
len(full_arr)
# Out:
# 366

# %%
from math import factorial as fact
from time import time
def solution(n):
    generate = lambda x, i: int(fact(x)/fact(x-i))  # fact
    MAX_RESULT = 10**12  # 정답이 10^12 이하인 경우만 입력으로 주어집니다.
    for i in range(MAX_RESULT):  # 정답의 범위에 의해 최대 몇 개의 곱까지 가능한지 결정
        if fact(i) > MAX_RESULT:
            MAX_RANGE = i
            break
    n_set=set()  # 중복을 제거하기 위한 set
    holding_number = {}  # set에 넣을 다음 최솟값을 갖고 있음
    n_for_next = {}  # holding_number{}에서 다음 곱을 갖기 위한 정보 저장
    for x in range(2, MAX_RANGE):
        n_for_next[x] = x  # 초기값 2~MAX_RANGE
    for i in range(2, MAX_RANGE):
        holding_number[i] = i
    
    for x in range(2, MAX_RANGE):
        holding_number[x] = generate(x, x)

    while len(n_set) < n:
        min_value = min(holding_number.values())
        min_key = [key for key, value in holding_number.items() if value == min_value][0]
        n_set.add(min_value)
#         if min_value == 40200:
#             print(min_key)
#             return False
#         print(min_value)
        
        new_n = n_for_next[min_key]+1 
        n_for_next[min_key] = new_n
        new_value = generate(new_n, min_key)
        holding_number[min_key] = new_value
        
    arr = list(n_set)
    arr.sort()
    return arr[n-1]
start_time = time()
end_i = 0
end_time_arr=[]
for i in range(1, 1000000):
    print('n : {}   result : {}'.format(i, solution(i)))
#     end_time = time()
    end_i = i
#     if i%100 == 0:
#         end_time_arr.append(time())
    end_time_arr.append(time())
# end_time = time()
# Out:
# n : 1   result : 2
# n : 2   result : 6
# n : 3   result : 12
# n : 4   result : 20
# n : 5   result : 24
# n : 6   result : 30
# n : 7   result : 42
# n : 8   result : 56
# n : 9   result : 60
# n : 10   result : 72
# n : 11   result : 90
# n : 12   result : 110
# n : 13   result : 120
# n : 14   result : 132
# n : 15   result : 156
# n : 16   result : 182
# n : 17   result : 210
# n : 18   result : 240
# n : 19   result : 272
# n : 20   result : 306
# n : 21   result : 336
# n : 22   result : 342
# n : 23   result : 360
# n : 24   result : 380
# n : 25   result : 420
# n : 26   result : 462
# n : 27   result : 504
# n : 28   result : 506
# n : 29   result : 552
# n : 30   result : 600
# n : 933   result : 655290
# n : 934   result : 656910
# n : 935   result : 657720
# n : 936   result : 658416
# n : 937   result : 658532
# n : 938   result : 660156
# n : 939   result : 661782
# n : 940   result : 663410
# n : 941   result : 665040
# n : 942   result : 665280
# n : 943   result : 666672
# n : 944   result : 668306
# n : 945   result : 669942
# n : 946   result : 671580
# n : 947   result : 673220
# n : 948   result : 674862
# n : 949   result : 676506
# n : 950   result : 678152
# n : 951   result : 679800
# n : 952   result : 681384
# n : 953   result : 681450
# n : 954   result : 683102
# n : 955   result : 684756
# n : 956   result : 686412
# n : 957   result : 688070
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-a720e1faa9d6> in <module>
#      40 end_time_arr=[]
#      41 for i in range(1, 1000000):
# ---> 42     print('n : {}   result : {}'.format(i, solution(i)))
#      43 #     end_time = time()
#      44     end_i = i
#
# <ipython-input-217-a720e1faa9d6> in solution(n)
#      30         new_n = n_for_next[min_key]+1
#      31         n_for_next[min_key] = new_n
# ---> 32         new_value = generate(new_n, min_key)
#      33         holding_number[min_key] = new_value
#      34
#
# <ipython-input-217-a720e1faa9d6> in <lambda>(x, i)
#       2 from time import time
#       3 def solution(n):
# ----> 4     generate = lambda x, i: int(fact(x)/fact(x-i))
#       5     MAX_RESULT = 10**12  # 정답이 10^12 이하인 경우만 입력으로 주어집니다.
#       6     for i in range(MAX_RESULT):
#
# KeyboardInterrupt:

# %%
from time import time
global LOG
LOG = False  # default:False
def factorial(x, y):  # factorial(x,x) = x! , factorial(x,2) = x * (x-1) , factorial(x,n) = n회 곱
    result = 1
    for i in range(0, y):  # (x-0) * (x-1) * ... * (x-y+1)
        result *= x-i
    return result

def solution(n):
    global LOG  # 로그를 남기기 위한 On / Off
    MAX_RESULT = 10**12  # 정답이 10^12 이하인 경우만 입력으로 주어집니다.
    for i in range(MAX_RESULT):  # 정답의 범위에 의해 최대 몇 개의 곱까지 가능한지 결정
        if factorial(i, i) > MAX_RESULT:
            MAX_RANGE = i
            break
    n_set=set()  # 중복을 제거하기 위한 set
    holding_number = {}  # set에 넣을 다음 최솟값을 갖고 있음
    n_for_next = {}  # holding_number{}에서 다음 곱을 갖기 위한 정보 저장
    if LOG:  # Log를 남김. default:False
        log_arr = []
    
    for x in range(2, MAX_RANGE):
        n_for_next[x] = x
    for x in range(2, MAX_RANGE):
        holding_number[x] = factorial(x, x-1)  # {2:2, 3:6, ... , MAX_RANGE:MAX_RANGE*(MAX_RANGE-1)}

    while len(n_set) < n:  # n번째 값을 찾기 위해 중복이 제외된 len(set)의 크기를 n까지 반복
        min_value = min(holding_number.values())  # (dict)holding_number에서 가진 최소 value
        min_key = [key for key, value in holding_number.items() 
                   if value == min_value][0]  # 최솟값의 key를 저장
        n_set.add(min_value)  # set에 최솟값 저장
        
        if LOG:  # 로그를 위한 배열에 저장. default:False
            log_arr.append([min_value, n_for_next[min_key], min_key])
            
        new_n = n_for_next[min_key]+1  # 다음 곱을 얻기 위한 값 ex)2*1 -> 3*2 -> 4*3 .. -> n*(n-1)
        n_for_next[min_key] = new_n  # 방금 뽑았던 최솟값의 키에 다음 곱을 시작하는 n값 저장
        new_value = factorial(new_n, min_key)  # 방금 뽑은 키에 다음 곱 계산
        holding_number[min_key] = new_value  # 계산된 다음 곱을 방금 뽑은 키에 저장
        
    arr = list(n_set)  # 정렬을 위한 배열화
    arr.sort()
    if LOG:  # LOG=True일 경우 로그 배열 반환
        return log_arr
    else:
        return arr[n-1]
    
def wrong_solution(n):
    arr = list(range(0, n+10))
    x, y = 2, 1
    for i in range(n+10):
        if i != 0 and i%4 == 0:
            arr[i] = x * (x+1) * (x+2)
            x += 1
        else:
            arr[i] = y * (y+1)
            y += 1
    arr = set(arr)
    arr = list(arr)
    arr.sort()
    return arr[n-1]

# for i in range(1, 2000):
#     a = solution2(i)
#     b = wrong_solution(i)
#     if a != b:
#         print('Wrong Value at n:{}, result: {} and {}'.format(i, a, b))

# %%
start_time = time()
end_i = 0
end_time_arr=[]
TIME_SIZE = 100  # 몇 회당 시간을 확인할 것인지
LOG_SIZE = 1000  # n이 몇일 때까지 시간을 확인할 것인지
for i in range(1, LOG_SIZE+1):
    x = solution(i)
    end_time = time()
    end_i = i
    if i%TIME_SIZE == 0:
        end_time_arr.append(time())
end_time = time()
n = 1
for i in end_time_arr:
    print('size at {0:5d} elapsed {1:5.2f} seconds'.format(TIME_SIZE*n, round(i - start_time,2)))
    n += 1
# Out:
# size at   100 elapsed  0.01 seconds
# size at   200 elapsed  0.04 seconds
# size at   300 elapsed  0.08 seconds
# size at   400 elapsed  0.15 seconds
# size at   500 elapsed  0.23 seconds
# size at   600 elapsed  0.32 seconds
# size at   700 elapsed  0.45 seconds
# size at   800 elapsed  0.58 seconds
# size at   900 elapsed  0.73 seconds
# size at  1000 elapsed  0.89 seconds

# %%
if LOG:
    LOG_SIZE = 1000
    test_arr = solution(LOG_SIZE)
    same = 0
    was_not_2 = False
    rule, add = [], []
    n = 1
    for x in test_arr:
        s = str(x[1])
        for i in range(1, x[2]):
            s += '*'+str(x[1]-i)
        if same != x[0]:
            if x[2] == 2 and was_not_2:
                print()
                rule.append(add)
                add = []
                was_not_2 = False
            elif x[2] != 2:
                was_not_2 = True
            if x[2] >=4:
                print('{0:14s} = {1:10d} , {2:8d}개의 곱 , n = {3}'.format(s, x[0], x[2], n))
                n += 1
            else:
                print('{0:14s} = {1:10d} , {2:8d}개의 곱 , n = {3}'.format(s, x[0], x[2], n))
                n += 1
            add.append(x[2])
        else:
            pass
            print('{0:14s} = 중복{1:6d} , {2:8d}개의 곱 , n = {3}'.format(s, x[0], x[2], n-1))
            add.append(x[2])
            if x[2] != 2:
                was_not_2 = True
        same = x[0]
# Out:
# 2*1            =          2 ,        2개의 곱 , n = 1
# 3*2            =          6 ,        2개의 곱 , n = 2
# 3*2*1          = 중복     6 ,        3개의 곱 , n = 2
#
# 4*3            =         12 ,        2개의 곱 , n = 3
# 5*4            =         20 ,        2개의 곱 , n = 4
# 4*3*2          =         24 ,        3개의 곱 , n = 5
# 4*3*2*1        = 중복    24 ,        4개의 곱 , n = 5
#
# 6*5            =         30 ,        2개의 곱 , n = 6
# 7*6            =         42 ,        2개의 곱 , n = 7
# 8*7            =         56 ,        2개의 곱 , n = 8
# 5*4*3          =         60 ,        3개의 곱 , n = 9
#
# 9*8            =         72 ,        2개의 곱 , n = 10
# 10*9           =         90 ,        2개의 곱 , n = 11
# 11*10          =        110 ,        2개의 곱 , n = 12
# 6*5*4          =        120 ,        3개의 곱 , n = 13
# 5*4*3*2        = 중복   120 ,        4개의 곱 , n = 13
# 5*4*3*2*1      = 중복   120 ,        5개의 곱 , n = 13
#
# 12*11          =        132 ,        2개의 곱 , n = 14
# 13*12          =        156 ,        2개의 곱 , n = 15
# 14*13          =        182 ,        2개의 곱 , n = 16
# 15*14          =        210 ,        2개의 곱 , n = 17
# 7*6*5          = 중복   210 ,        3개의 곱 , n = 17
#
# 16*15          =        240 ,        2개의 곱 , n = 18
# 17*16          =        272 ,        2개의 곱 , n = 19
# 18*17          =        306 ,        2개의 곱 , n = 20
# 8*7*6          =        336 ,        3개의 곱 , n = 21
#
# 19*18          =        342 ,        2개의 곱 , n = 22
# 6*5*4*3        =        360 ,        4개의 곱 , n = 23
#
# 20*19          =        380 ,        2개의 곱 , n = 24
# 21*20          =        420 ,        2개의 곱 , n = 25
# 22*21          =        462 ,        2개의 곱 , n = 26
# 9*8*7          =        504 ,        3개의 곱 , n = 27
#
# 23*22          =        506 ,        2개의 곱 , n = 28
# 24*23          =        552 ,        2개의 곱 , n = 29
# 25*24          =        600 ,        2개의 곱 , n = 30
# 26*25          =        650 ,        2개의 곱 , n = 31
# 27*26          =        702 ,        2개의 곱 , n = 32
# 10*9*8         =        720 ,        3개의 곱 , n = 33
# 6*5*4*3*2      = 중복   720 ,        5개의 곱 , n = 33
# 6*5*4*3*2*1    = 중복   720 ,        6개의 곱 , n = 33
#
# 28*27          =        756 ,        2개의 곱 , n = 34
# 29*28          =        812 ,        2개의 곱 , n = 35
# 7*6*5*4        =        840 ,        4개의 곱 , n = 36
#
# 30*29          =        870 ,        2개의 곱 , n = 37
# 31*30          =        930 ,        2개의 곱 , n = 38
# 11*10*9        =        990 ,        3개의 곱 , n = 39
#
# 32*31          =        992 ,        2개의 곱 , n = 40
# 33*32          =       1056 ,        2개의 곱 , n = 41
# 34*33          =       1122 ,        2개의 곱 , n = 42
# 35*34          =       1190 ,        2개의 곱 , n = 43
# 36*35          =       1260 ,        2개의 곱 , n = 44
# 12*11*10       =       1320 ,        3개의 곱 , n = 45
#
# 37*36          =       1332 ,        2개의 곱 , n = 46
# 38*37          =       1406 ,        2개의 곱 , n = 47
# 39*38          =       1482 ,        2개의 곱 , n = 48
# 40*39          =       1560 ,        2개의 곱 , n = 49
# 41*40          =       1640 ,        2개의 곱 , n = 50
# 8*7*6*5        =       1680 ,        4개의 곱 , n = 51
# 13*12*11       =       1716 ,        3개의 곱 , n = 52
#
# 42*41          =       1722 ,        2개의 곱 , n = 53
# 43*42          =       1806 ,        2개의 곱 , n = 54
# 44*43          =       1892 ,        2개의 곱 , n = 55
# 45*44          =       1980 ,        2개의 곱 , n = 56
# 46*45          =       2070 ,        2개의 곱 , n = 57
# 47*46          =       2162 ,        2개의 곱 , n = 58
# 14*13*12       =       2184 ,        3개의 곱 , n = 59
#
# 48*47          =       2256 ,        2개의 곱 , n = 60
# 49*48          =       2352 ,        2개의 곱 , n = 61
# 50*49          =       2450 ,        2개의 곱 , n = 62
# 7*6*5*4*3      =       2520 ,        5개의 곱 , n = 63
#
# 51*50          =       2550 ,        2개의 곱 , n = 64
# 52*51          =       2652 ,        2개의 곱 , n = 65
# 15*14*13       =       2730 ,        3개의 곱 , n = 66
#
# 53*52          =       2756 ,        2개의 곱 , n = 67
# 54*53          =       2862 ,        2개의 곱 , n = 68
# 55*54          =       2970 ,        2개의 곱 , n = 69
# 9*8*7*6        =       3024 ,        4개의 곱 , n = 70
#
# 56*55          =       3080 ,        2개의 곱 , n = 71
# 57*56          =       3192 ,        2개의 곱 , n = 72
# 58*57          =       3306 ,        2개의 곱 , n = 73
# 16*15*14       =       3360 ,        3개의 곱 , n = 74
#
# 59*58          =       3422 ,        2개의 곱 , n = 75
# 60*59          =       3540 ,        2개의 곱 , n = 76
# 61*60          =       3660 ,        2개의 곱 , n = 77
# 62*61          =       3782 ,        2개의 곱 , n = 78
# 63*62          =       3906 ,        2개의 곱 , n = 79
# 64*63          =       4032 ,        2개의 곱 , n = 80
# 17*16*15       =       4080 ,        3개의 곱 , n = 81
#
# 65*64          =       4160 ,        2개의 곱 , n = 82
# 66*65          =       4290 ,        2개의 곱 , n = 83
# 67*66          =       4422 ,        2개의 곱 , n = 84
# 68*67          =       4556 ,        2개의 곱 , n = 85
# 69*68          =       4692 ,        2개의 곱 , n = 86
# 70*69          =       4830 ,        2개의 곱 , n = 87
# 18*17*16       =       4896 ,        3개의 곱 , n = 88
#
# 71*70          =       4970 ,        2개의 곱 , n = 89
# 10*9*8*7       =       5040 ,        4개의 곱 , n = 90
# 7*6*5*4*3*2    = 중복  5040 ,        6개의 곱 , n = 90
# 7*6*5*4*3*2*1  = 중복  5040 ,        7개의 곱 , n = 90
#
# 72*71          =       5112 ,        2개의 곱 , n = 91
# 73*72          =       5256 ,        2개의 곱 , n = 92
# 74*73          =       5402 ,        2개의 곱 , n = 93
# 75*74          =       5550 ,        2개의 곱 , n = 94
# 76*75          =       5700 ,        2개의 곱 , n = 95
# 19*18*17       =       5814 ,        3개의 곱 , n = 96
#
# 77*76          =       5852 ,        2개의 곱 , n = 97
# 78*77          =       6006 ,        2개의 곱 , n = 98
# 79*78          =       6162 ,        2개의 곱 , n = 99
# 80*79          =       6320 ,        2개의 곱 , n = 100
# 81*80          =       6480 ,        2개의 곱 , n = 101
# 82*81          =       6642 ,        2개의 곱 , n = 102
# 8*7*6*5*4      =       6720 ,        5개의 곱 , n = 103
#
# 83*82          =       6806 ,        2개의 곱 , n = 104
# 20*19*18       =       6840 ,        3개의 곱 , n = 105
#
# 84*83          =       6972 ,        2개의 곱 , n = 106
# 85*84          =       7140 ,        2개의 곱 , n = 107
# 86*85          =       7310 ,        2개의 곱 , n = 108
# 87*86          =       7482 ,        2개의 곱 , n = 109
# 88*87          =       7656 ,        2개의 곱 , n = 110
# 89*88          =       7832 ,        2개의 곱 , n = 111
# 11*10*9*8      =       7920 ,        4개의 곱 , n = 112
# 21*20*19       =       7980 ,        3개의 곱 , n = 113
#
# 90*89          =       8010 ,        2개의 곱 , n = 114
# 91*90          =       8190 ,        2개의 곱 , n = 115
# 92*91          =       8372 ,        2개의 곱 , n = 116
# 93*92          =       8556 ,        2개의 곱 , n = 117
# 94*93          =       8742 ,        2개의 곱 , n = 118
# 95*94          =       8930 ,        2개의 곱 , n = 119
# 96*95          =       9120 ,        2개의 곱 , n = 120
# 22*21*20       =       9240 ,        3개의 곱 , n = 121
#
# 97*96          =       9312 ,        2개의 곱 , n = 122
# 98*97          =       9506 ,        2개의 곱 , n = 123
# 99*98          =       9702 ,        2개의 곱 , n = 124
# 100*99         =       9900 ,        2개의 곱 , n = 125
# 101*100        =      10100 ,        2개의 곱 , n = 126
# 102*101        =      10302 ,        2개의 곱 , n = 127
# 103*102        =      10506 ,        2개의 곱 , n = 128
# 23*22*21       =      10626 ,        3개의 곱 , n = 129
#
# 104*103        =      10712 ,        2개의 곱 , n = 130
# 105*104        =      10920 ,        2개의 곱 , n = 131
# 106*105        =      11130 ,        2개의 곱 , n = 132
# 107*106        =      11342 ,        2개의 곱 , n = 133
# 108*107        =      11556 ,        2개의 곱 , n = 134
# 109*108        =      11772 ,        2개의 곱 , n = 135
# 12*11*10*9     =      11880 ,        4개의 곱 , n = 136
#
# 110*109        =      11990 ,        2개의 곱 , n = 137
# 24*23*22       =      12144 ,        3개의 곱 , n = 138
#
# 111*110        =      12210 ,        2개의 곱 , n = 139
# 112*111        =      12432 ,        2개의 곱 , n = 140
# 113*112        =      12656 ,        2개의 곱 , n = 141
# 114*113        =      12882 ,        2개의 곱 , n = 142
# 115*114        =      13110 ,        2개의 곱 , n = 143
# 116*115        =      13340 ,        2개의 곱 , n = 144
# 117*116        =      13572 ,        2개의 곱 , n = 145
# 25*24*23       =      13800 ,        3개의 곱 , n = 146
#
# 118*117        =      13806 ,        2개의 곱 , n = 147
# 119*118        =      14042 ,        2개의 곱 , n = 148
# 120*119        =      14280 ,        2개의 곱 , n = 149
# 121*120        =      14520 ,        2개의 곱 , n = 150
# 122*121        =      14762 ,        2개의 곱 , n = 151
# 123*122        =      15006 ,        2개의 곱 , n = 152
# 9*8*7*6*5      =      15120 ,        5개의 곱 , n = 153
#
# 124*123        =      15252 ,        2개의 곱 , n = 154
# 125*124        =      15500 ,        2개의 곱 , n = 155
# 26*25*24       =      15600 ,        3개의 곱 , n = 156
#
# 126*125        =      15750 ,        2개의 곱 , n = 157
# 127*126        =      16002 ,        2개의 곱 , n = 158
# 128*127        =      16256 ,        2개의 곱 , n = 159
# 129*128        =      16512 ,        2개의 곱 , n = 160
# 130*129        =      16770 ,        2개의 곱 , n = 161
# 131*130        =      17030 ,        2개의 곱 , n = 162
# 13*12*11*10    =      17160 ,        4개의 곱 , n = 163
#
# 132*131        =      17292 ,        2개의 곱 , n = 164
# 27*26*25       =      17550 ,        3개의 곱 , n = 165
#
# 133*132        =      17556 ,        2개의 곱 , n = 166
# 134*133        =      17822 ,        2개의 곱 , n = 167
# 135*134        =      18090 ,        2개의 곱 , n = 168
# 136*135        =      18360 ,        2개의 곱 , n = 169
# 137*136        =      18632 ,        2개의 곱 , n = 170
# 138*137        =      18906 ,        2개의 곱 , n = 171
# 139*138        =      19182 ,        2개의 곱 , n = 172
# 140*139        =      19460 ,        2개의 곱 , n = 173
# 28*27*26       =      19656 ,        3개의 곱 , n = 174
#
# 141*140        =      19740 ,        2개의 곱 , n = 175
# 142*141        =      20022 ,        2개의 곱 , n = 176
# 8*7*6*5*4*3    =      20160 ,        6개의 곱 , n = 177
#
# 143*142        =      20306 ,        2개의 곱 , n = 178
# 144*143        =      20592 ,        2개의 곱 , n = 179
# 145*144        =      20880 ,        2개의 곱 , n = 180
# 146*145        =      21170 ,        2개의 곱 , n = 181
# 147*146        =      21462 ,        2개의 곱 , n = 182
# 148*147        =      21756 ,        2개의 곱 , n = 183
# 29*28*27       =      21924 ,        3개의 곱 , n = 184
#
# 149*148        =      22052 ,        2개의 곱 , n = 185
# 150*149        =      22350 ,        2개의 곱 , n = 186
# 151*150        =      22650 ,        2개의 곱 , n = 187
# 152*151        =      22952 ,        2개의 곱 , n = 188
# 153*152        =      23256 ,        2개의 곱 , n = 189
# 154*153        =      23562 ,        2개의 곱 , n = 190
# 155*154        =      23870 ,        2개의 곱 , n = 191
# 14*13*12*11    =      24024 ,        4개의 곱 , n = 192
#
# 156*155        =      24180 ,        2개의 곱 , n = 193
# 30*29*28       =      24360 ,        3개의 곱 , n = 194
#
# 157*156        =      24492 ,        2개의 곱 , n = 195
# 158*157        =      24806 ,        2개의 곱 , n = 196
# 159*158        =      25122 ,        2개의 곱 , n = 197
# 160*159        =      25440 ,        2개의 곱 , n = 198
# 161*160        =      25760 ,        2개의 곱 , n = 199
# 162*161        =      26082 ,        2개의 곱 , n = 200
# 163*162        =      26406 ,        2개의 곱 , n = 201
# 164*163        =      26732 ,        2개의 곱 , n = 202
# 31*30*29       =      26970 ,        3개의 곱 , n = 203
#
# 165*164        =      27060 ,        2개의 곱 , n = 204
# 166*165        =      27390 ,        2개의 곱 , n = 205
# 167*166        =      27722 ,        2개의 곱 , n = 206
# 168*167        =      28056 ,        2개의 곱 , n = 207
# 169*168        =      28392 ,        2개의 곱 , n = 208
# 170*169        =      28730 ,        2개의 곱 , n = 209
# 171*170        =      29070 ,        2개의 곱 , n = 210
# 172*171        =      29412 ,        2개의 곱 , n = 211
# 173*172        =      29756 ,        2개의 곱 , n = 212
# 32*31*30       =      29760 ,        3개의 곱 , n = 213
#
# 174*173        =      30102 ,        2개의 곱 , n = 214
# 10*9*8*7*6     =      30240 ,        5개의 곱 , n = 215
#
# 175*174        =      30450 ,        2개의 곱 , n = 216
# 176*175        =      30800 ,        2개의 곱 , n = 217
# 177*176        =      31152 ,        2개의 곱 , n = 218
# 178*177        =      31506 ,        2개의 곱 , n = 219
# 179*178        =      31862 ,        2개의 곱 , n = 220
# 180*179        =      32220 ,        2개의 곱 , n = 221
# 181*180        =      32580 ,        2개의 곱 , n = 222
# 33*32*31       =      32736 ,        3개의 곱 , n = 223
# 15*14*13*12    =      32760 ,        4개의 곱 , n = 224
#
# 182*181        =      32942 ,        2개의 곱 , n = 225
# 183*182        =      33306 ,        2개의 곱 , n = 226
# 184*183        =      33672 ,        2개의 곱 , n = 227
# 185*184        =      34040 ,        2개의 곱 , n = 228
# 186*185        =      34410 ,        2개의 곱 , n = 229
# 187*186        =      34782 ,        2개의 곱 , n = 230
# 188*187        =      35156 ,        2개의 곱 , n = 231
# 189*188        =      35532 ,        2개의 곱 , n = 232
# 34*33*32       =      35904 ,        3개의 곱 , n = 233
#
# 190*189        =      35910 ,        2개의 곱 , n = 234
# 191*190        =      36290 ,        2개의 곱 , n = 235
# 192*191        =      36672 ,        2개의 곱 , n = 236
# 193*192        =      37056 ,        2개의 곱 , n = 237
# 194*193        =      37442 ,        2개의 곱 , n = 238
# 195*194        =      37830 ,        2개의 곱 , n = 239
# 196*195        =      38220 ,        2개의 곱 , n = 240
# 197*196        =      38612 ,        2개의 곱 , n = 241
# 198*197        =      39006 ,        2개의 곱 , n = 242
# 35*34*33       =      39270 ,        3개의 곱 , n = 243
#
# 199*198        =      39402 ,        2개의 곱 , n = 244
# 200*199        =      39800 ,        2개의 곱 , n = 245
# 201*200        =      40200 ,        2개의 곱 , n = 246
# 8*7*6*5*4*3*2  =      40320 ,        7개의 곱 , n = 247
# 8*7*6*5*4*3*2*1 = 중복 40320 ,        8개의 곱 , n = 247
#
# 202*201        =      40602 ,        2개의 곱 , n = 248
# 203*202        =      41006 ,        2개의 곱 , n = 249
# 204*203        =      41412 ,        2개의 곱 , n = 250
# 205*204        =      41820 ,        2개의 곱 , n = 251
# 206*205        =      42230 ,        2개의 곱 , n = 252
# 207*206        =      42642 ,        2개의 곱 , n = 253
# 36*35*34       =      42840 ,        3개의 곱 , n = 254
#
# 208*207        =      43056 ,        2개의 곱 , n = 255
# 209*208        =      43472 ,        2개의 곱 , n = 256
# 16*15*14*13    =      43680 ,        4개의 곱 , n = 257
#
# 210*209        =      43890 ,        2개의 곱 , n = 258
# 211*210        =      44310 ,        2개의 곱 , n = 259
# 212*211        =      44732 ,        2개의 곱 , n = 260
# 213*212        =      45156 ,        2개의 곱 , n = 261
# 214*213        =      45582 ,        2개의 곱 , n = 262
# 215*214        =      46010 ,        2개의 곱 , n = 263
# 216*215        =      46440 ,        2개의 곱 , n = 264
# 37*36*35       =      46620 ,        3개의 곱 , n = 265
#
# 217*216        =      46872 ,        2개의 곱 , n = 266
# 218*217        =      47306 ,        2개의 곱 , n = 267
# 219*218        =      47742 ,        2개의 곱 , n = 268
# 220*219        =      48180 ,        2개의 곱 , n = 269
# 221*220        =      48620 ,        2개의 곱 , n = 270
# 222*221        =      49062 ,        2개의 곱 , n = 271
# 223*222        =      49506 ,        2개의 곱 , n = 272
# 224*223        =      49952 ,        2개의 곱 , n = 273
# 225*224        =      50400 ,        2개의 곱 , n = 274
# 38*37*36       =      50616 ,        3개의 곱 , n = 275
#
# 226*225        =      50850 ,        2개의 곱 , n = 276
# 227*226        =      51302 ,        2개의 곱 , n = 277
# 228*227        =      51756 ,        2개의 곱 , n = 278
# 229*228        =      52212 ,        2개의 곱 , n = 279
# 230*229        =      52670 ,        2개의 곱 , n = 280
# 231*230        =      53130 ,        2개의 곱 , n = 281
# 232*231        =      53592 ,        2개의 곱 , n = 282
# 233*232        =      54056 ,        2개의 곱 , n = 283
# 234*233        =      54522 ,        2개의 곱 , n = 284
# 39*38*37       =      54834 ,        3개의 곱 , n = 285
#
# 235*234        =      54990 ,        2개의 곱 , n = 286
# 11*10*9*8*7    =      55440 ,        5개의 곱 , n = 287
#
# 236*235        =      55460 ,        2개의 곱 , n = 288
# 237*236        =      55932 ,        2개의 곱 , n = 289
# 238*237        =      56406 ,        2개의 곱 , n = 290
# 239*238        =      56882 ,        2개의 곱 , n = 291
# 17*16*15*14    =      57120 ,        4개의 곱 , n = 292
#
# 240*239        =      57360 ,        2개의 곱 , n = 293
# 241*240        =      57840 ,        2개의 곱 , n = 294
# 242*241        =      58322 ,        2개의 곱 , n = 295
# 243*242        =      58806 ,        2개의 곱 , n = 296
# 40*39*38       =      59280 ,        3개의 곱 , n = 297
#
# 244*243        =      59292 ,        2개의 곱 , n = 298
# 245*244        =      59780 ,        2개의 곱 , n = 299
# 246*245        =      60270 ,        2개의 곱 , n = 300
# 9*8*7*6*5*4    =      60480 ,        6개의 곱 , n = 301
#
# 247*246        =      60762 ,        2개의 곱 , n = 302
# 248*247        =      61256 ,        2개의 곱 , n = 303
# 249*248        =      61752 ,        2개의 곱 , n = 304
# 250*249        =      62250 ,        2개의 곱 , n = 305
# 251*250        =      62750 ,        2개의 곱 , n = 306
# 252*251        =      63252 ,        2개의 곱 , n = 307
# 253*252        =      63756 ,        2개의 곱 , n = 308
# 41*40*39       =      63960 ,        3개의 곱 , n = 309
#
# 254*253        =      64262 ,        2개의 곱 , n = 310
# 255*254        =      64770 ,        2개의 곱 , n = 311
# 256*255        =      65280 ,        2개의 곱 , n = 312
# 257*256        =      65792 ,        2개의 곱 , n = 313
# 258*257        =      66306 ,        2개의 곱 , n = 314
# 259*258        =      66822 ,        2개의 곱 , n = 315
# 260*259        =      67340 ,        2개의 곱 , n = 316
# 261*260        =      67860 ,        2개의 곱 , n = 317
# 262*261        =      68382 ,        2개의 곱 , n = 318
# 42*41*40       =      68880 ,        3개의 곱 , n = 319
#
# 263*262        =      68906 ,        2개의 곱 , n = 320
# 264*263        =      69432 ,        2개의 곱 , n = 321
# 265*264        =      69960 ,        2개의 곱 , n = 322
# 266*265        =      70490 ,        2개의 곱 , n = 323
# 267*266        =      71022 ,        2개의 곱 , n = 324
# 268*267        =      71556 ,        2개의 곱 , n = 325
# 269*268        =      72092 ,        2개의 곱 , n = 326
# 270*269        =      72630 ,        2개의 곱 , n = 327
# 271*270        =      73170 ,        2개의 곱 , n = 328
# 18*17*16*15    =      73440 ,        4개의 곱 , n = 329
#
# 272*271        =      73712 ,        2개의 곱 , n = 330
# 43*42*41       =      74046 ,        3개의 곱 , n = 331
#
# 273*272        =      74256 ,        2개의 곱 , n = 332
# 274*273        =      74802 ,        2개의 곱 , n = 333
# 275*274        =      75350 ,        2개의 곱 , n = 334
# 276*275        =      75900 ,        2개의 곱 , n = 335
# 277*276        =      76452 ,        2개의 곱 , n = 336
# 278*277        =      77006 ,        2개의 곱 , n = 337
# 279*278        =      77562 ,        2개의 곱 , n = 338
# 280*279        =      78120 ,        2개의 곱 , n = 339
# 281*280        =      78680 ,        2개의 곱 , n = 340
# 282*281        =      79242 ,        2개의 곱 , n = 341
# 44*43*42       =      79464 ,        3개의 곱 , n = 342
#
# 283*282        =      79806 ,        2개의 곱 , n = 343
# 284*283        =      80372 ,        2개의 곱 , n = 344
# 285*284        =      80940 ,        2개의 곱 , n = 345
# 286*285        =      81510 ,        2개의 곱 , n = 346
# 287*286        =      82082 ,        2개의 곱 , n = 347
# 288*287        =      82656 ,        2개의 곱 , n = 348
# 289*288        =      83232 ,        2개의 곱 , n = 349
# 290*289        =      83810 ,        2개의 곱 , n = 350
# 291*290        =      84390 ,        2개의 곱 , n = 351
# 292*291        =      84972 ,        2개의 곱 , n = 352
# 45*44*43       =      85140 ,        3개의 곱 , n = 353
#
# 293*292        =      85556 ,        2개의 곱 , n = 354
# 294*293        =      86142 ,        2개의 곱 , n = 355
# 295*294        =      86730 ,        2개의 곱 , n = 356
# 296*295        =      87320 ,        2개의 곱 , n = 357
# 297*296        =      87912 ,        2개의 곱 , n = 358
# 298*297        =      88506 ,        2개의 곱 , n = 359
# 299*298        =      89102 ,        2개의 곱 , n = 360
# 300*299        =      89700 ,        2개의 곱 , n = 361
# 301*300        =      90300 ,        2개의 곱 , n = 362
# 302*301        =      90902 ,        2개의 곱 , n = 363
# 46*45*44       =      91080 ,        3개의 곱 , n = 364
#
# 303*302        =      91506 ,        2개의 곱 , n = 365
# 304*303        =      92112 ,        2개의 곱 , n = 366
# 305*304        =      92720 ,        2개의 곱 , n = 367
# 19*18*17*16    =      93024 ,        4개의 곱 , n = 368
#
# 306*305        =      93330 ,        2개의 곱 , n = 369
# 307*306        =      93942 ,        2개의 곱 , n = 370
# 308*307        =      94556 ,        2개의 곱 , n = 371
# 12*11*10*9*8   =      95040 ,        5개의 곱 , n = 372
#
# 309*308        =      95172 ,        2개의 곱 , n = 373
# 310*309        =      95790 ,        2개의 곱 , n = 374
# 311*310        =      96410 ,        2개의 곱 , n = 375
# 312*311        =      97032 ,        2개의 곱 , n = 376
# 47*46*45       =      97290 ,        3개의 곱 , n = 377
#
# 313*312        =      97656 ,        2개의 곱 , n = 378
# 314*313        =      98282 ,        2개의 곱 , n = 379
# 315*314        =      98910 ,        2개의 곱 , n = 380
# 316*315        =      99540 ,        2개의 곱 , n = 381
# 317*316        =     100172 ,        2개의 곱 , n = 382
# 318*317        =     100806 ,        2개의 곱 , n = 383
# 319*318        =     101442 ,        2개의 곱 , n = 384
# 320*319        =     102080 ,        2개의 곱 , n = 385
# 321*320        =     102720 ,        2개의 곱 , n = 386
# 322*321        =     103362 ,        2개의 곱 , n = 387
# 48*47*46       =     103776 ,        3개의 곱 , n = 388
#
# 323*322        =     104006 ,        2개의 곱 , n = 389
# 324*323        =     104652 ,        2개의 곱 , n = 390
# 325*324        =     105300 ,        2개의 곱 , n = 391
# 326*325        =     105950 ,        2개의 곱 , n = 392
# 327*326        =     106602 ,        2개의 곱 , n = 393
# 328*327        =     107256 ,        2개의 곱 , n = 394
# 329*328        =     107912 ,        2개의 곱 , n = 395
# 330*329        =     108570 ,        2개의 곱 , n = 396
# 331*330        =     109230 ,        2개의 곱 , n = 397
# 332*331        =     109892 ,        2개의 곱 , n = 398
# 49*48*47       =     110544 ,        3개의 곱 , n = 399
#
# 333*332        =     110556 ,        2개의 곱 , n = 400
# 334*333        =     111222 ,        2개의 곱 , n = 401
# 335*334        =     111890 ,        2개의 곱 , n = 402
# 336*335        =     112560 ,        2개의 곱 , n = 403
# 337*336        =     113232 ,        2개의 곱 , n = 404
# 338*337        =     113906 ,        2개의 곱 , n = 405
# 339*338        =     114582 ,        2개의 곱 , n = 406
# 340*339        =     115260 ,        2개의 곱 , n = 407
# 341*340        =     115940 ,        2개의 곱 , n = 408
# 20*19*18*17    =     116280 ,        4개의 곱 , n = 409
#
# 342*341        =     116622 ,        2개의 곱 , n = 410
# 343*342        =     117306 ,        2개의 곱 , n = 411
# 50*49*48       =     117600 ,        3개의 곱 , n = 412
#
# 344*343        =     117992 ,        2개의 곱 , n = 413
# 345*344        =     118680 ,        2개의 곱 , n = 414
# 346*345        =     119370 ,        2개의 곱 , n = 415
# 347*346        =     120062 ,        2개의 곱 , n = 416
# 348*347        =     120756 ,        2개의 곱 , n = 417
# 349*348        =     121452 ,        2개의 곱 , n = 418
# 350*349        =     122150 ,        2개의 곱 , n = 419
# 351*350        =     122850 ,        2개의 곱 , n = 420
# 352*351        =     123552 ,        2개의 곱 , n = 421
# 353*352        =     124256 ,        2개의 곱 , n = 422
# 51*50*49       =     124950 ,        3개의 곱 , n = 423
#
# 354*353        =     124962 ,        2개의 곱 , n = 424
# 355*354        =     125670 ,        2개의 곱 , n = 425
# 356*355        =     126380 ,        2개의 곱 , n = 426
# 357*356        =     127092 ,        2개의 곱 , n = 427
# 358*357        =     127806 ,        2개의 곱 , n = 428
# 359*358        =     128522 ,        2개의 곱 , n = 429
# 360*359        =     129240 ,        2개의 곱 , n = 430
# 361*360        =     129960 ,        2개의 곱 , n = 431
# 362*361        =     130682 ,        2개의 곱 , n = 432
# 363*362        =     131406 ,        2개의 곱 , n = 433
# 364*363        =     132132 ,        2개의 곱 , n = 434
# 52*51*50       =     132600 ,        3개의 곱 , n = 435
#
# 365*364        =     132860 ,        2개의 곱 , n = 436
# 366*365        =     133590 ,        2개의 곱 , n = 437
# 367*366        =     134322 ,        2개의 곱 , n = 438
# 368*367        =     135056 ,        2개의 곱 , n = 439
# 369*368        =     135792 ,        2개의 곱 , n = 440
# 370*369        =     136530 ,        2개의 곱 , n = 441
# 371*370        =     137270 ,        2개의 곱 , n = 442
# 372*371        =     138012 ,        2개의 곱 , n = 443
# 373*372        =     138756 ,        2개의 곱 , n = 444
# 374*373        =     139502 ,        2개의 곱 , n = 445
# 375*374        =     140250 ,        2개의 곱 , n = 446
# 53*52*51       =     140556 ,        3개의 곱 , n = 447
#
# 376*375        =     141000 ,        2개의 곱 , n = 448
# 377*376        =     141752 ,        2개의 곱 , n = 449
# 378*377        =     142506 ,        2개의 곱 , n = 450
# 379*378        =     143262 ,        2개의 곱 , n = 451
# 21*20*19*18    =     143640 ,        4개의 곱 , n = 452
#
# 380*379        =     144020 ,        2개의 곱 , n = 453
# 381*380        =     144780 ,        2개의 곱 , n = 454
# 382*381        =     145542 ,        2개의 곱 , n = 455
# 383*382        =     146306 ,        2개의 곱 , n = 456
# 384*383        =     147072 ,        2개의 곱 , n = 457
# 385*384        =     147840 ,        2개의 곱 , n = 458
# 386*385        =     148610 ,        2개의 곱 , n = 459
# 54*53*52       =     148824 ,        3개의 곱 , n = 460
#
# 387*386        =     149382 ,        2개의 곱 , n = 461
# 388*387        =     150156 ,        2개의 곱 , n = 462
# 389*388        =     150932 ,        2개의 곱 , n = 463
# 10*9*8*7*6*5   =     151200 ,        6개의 곱 , n = 464
#
# 390*389        =     151710 ,        2개의 곱 , n = 465
# 391*390        =     152490 ,        2개의 곱 , n = 466
# 392*391        =     153272 ,        2개의 곱 , n = 467
# 393*392        =     154056 ,        2개의 곱 , n = 468
# 13*12*11*10*9  =     154440 ,        5개의 곱 , n = 469
#
# 394*393        =     154842 ,        2개의 곱 , n = 470
# 395*394        =     155630 ,        2개의 곱 , n = 471
# 396*395        =     156420 ,        2개의 곱 , n = 472
# 397*396        =     157212 ,        2개의 곱 , n = 473
# 55*54*53       =     157410 ,        3개의 곱 , n = 474
#
# 398*397        =     158006 ,        2개의 곱 , n = 475
# 399*398        =     158802 ,        2개의 곱 , n = 476
# 400*399        =     159600 ,        2개의 곱 , n = 477
# 401*400        =     160400 ,        2개의 곱 , n = 478
# 402*401        =     161202 ,        2개의 곱 , n = 479
# 403*402        =     162006 ,        2개의 곱 , n = 480
# 404*403        =     162812 ,        2개의 곱 , n = 481
# 405*404        =     163620 ,        2개의 곱 , n = 482
# 406*405        =     164430 ,        2개의 곱 , n = 483
# 407*406        =     165242 ,        2개의 곱 , n = 484
# 408*407        =     166056 ,        2개의 곱 , n = 485
# 56*55*54       =     166320 ,        3개의 곱 , n = 486
#
# 409*408        =     166872 ,        2개의 곱 , n = 487
# 410*409        =     167690 ,        2개의 곱 , n = 488
# 411*410        =     168510 ,        2개의 곱 , n = 489
# 412*411        =     169332 ,        2개의 곱 , n = 490
# 413*412        =     170156 ,        2개의 곱 , n = 491
# 414*413        =     170982 ,        2개의 곱 , n = 492
# 415*414        =     171810 ,        2개의 곱 , n = 493
# 416*415        =     172640 ,        2개의 곱 , n = 494
# 417*416        =     173472 ,        2개의 곱 , n = 495
# 418*417        =     174306 ,        2개의 곱 , n = 496
# 419*418        =     175142 ,        2개의 곱 , n = 497
# 57*56*55       =     175560 ,        3개의 곱 , n = 498
# 22*21*20*19    = 중복175560 ,        4개의 곱 , n = 498
#
# 420*419        =     175980 ,        2개의 곱 , n = 499
# 421*420        =     176820 ,        2개의 곱 , n = 500
# 422*421        =     177662 ,        2개의 곱 , n = 501
# 423*422        =     178506 ,        2개의 곱 , n = 502
# 424*423        =     179352 ,        2개의 곱 , n = 503
# 425*424        =     180200 ,        2개의 곱 , n = 504
# 426*425        =     181050 ,        2개의 곱 , n = 505
# 9*8*7*6*5*4*3  =     181440 ,        7개의 곱 , n = 506
#
# 427*426        =     181902 ,        2개의 곱 , n = 507
# 428*427        =     182756 ,        2개의 곱 , n = 508
# 429*428        =     183612 ,        2개의 곱 , n = 509
# 430*429        =     184470 ,        2개의 곱 , n = 510
# 58*57*56       =     185136 ,        3개의 곱 , n = 511
#
# 431*430        =     185330 ,        2개의 곱 , n = 512
# 432*431        =     186192 ,        2개의 곱 , n = 513
# 433*432        =     187056 ,        2개의 곱 , n = 514
# 434*433        =     187922 ,        2개의 곱 , n = 515
# 435*434        =     188790 ,        2개의 곱 , n = 516
# 436*435        =     189660 ,        2개의 곱 , n = 517
# 437*436        =     190532 ,        2개의 곱 , n = 518
# 438*437        =     191406 ,        2개의 곱 , n = 519
# 439*438        =     192282 ,        2개의 곱 , n = 520
# 440*439        =     193160 ,        2개의 곱 , n = 521
# 441*440        =     194040 ,        2개의 곱 , n = 522
# 442*441        =     194922 ,        2개의 곱 , n = 523
# 59*58*57       =     195054 ,        3개의 곱 , n = 524
#
# 443*442        =     195806 ,        2개의 곱 , n = 525
# 444*443        =     196692 ,        2개의 곱 , n = 526
# 445*444        =     197580 ,        2개의 곱 , n = 527
# 446*445        =     198470 ,        2개의 곱 , n = 528
# 447*446        =     199362 ,        2개의 곱 , n = 529
# 448*447        =     200256 ,        2개의 곱 , n = 530
# 449*448        =     201152 ,        2개의 곱 , n = 531
# 450*449        =     202050 ,        2개의 곱 , n = 532
# 451*450        =     202950 ,        2개의 곱 , n = 533
# 452*451        =     203852 ,        2개의 곱 , n = 534
# 453*452        =     204756 ,        2개의 곱 , n = 535
# 60*59*58       =     205320 ,        3개의 곱 , n = 536
#
# 454*453        =     205662 ,        2개의 곱 , n = 537
# 455*454        =     206570 ,        2개의 곱 , n = 538
# 456*455        =     207480 ,        2개의 곱 , n = 539
# 457*456        =     208392 ,        2개의 곱 , n = 540
# 458*457        =     209306 ,        2개의 곱 , n = 541
# 459*458        =     210222 ,        2개의 곱 , n = 542
# 460*459        =     211140 ,        2개의 곱 , n = 543
# 461*460        =     212060 ,        2개의 곱 , n = 544
# 23*22*21*20    =     212520 ,        4개의 곱 , n = 545
#
# 462*461        =     212982 ,        2개의 곱 , n = 546
# 463*462        =     213906 ,        2개의 곱 , n = 547
# 464*463        =     214832 ,        2개의 곱 , n = 548
# 465*464        =     215760 ,        2개의 곱 , n = 549
# 61*60*59       =     215940 ,        3개의 곱 , n = 550
#
# 466*465        =     216690 ,        2개의 곱 , n = 551
# 467*466        =     217622 ,        2개의 곱 , n = 552
# 468*467        =     218556 ,        2개의 곱 , n = 553
# 469*468        =     219492 ,        2개의 곱 , n = 554
# 470*469        =     220430 ,        2개의 곱 , n = 555
# 471*470        =     221370 ,        2개의 곱 , n = 556
# 472*471        =     222312 ,        2개의 곱 , n = 557
# 473*472        =     223256 ,        2개의 곱 , n = 558
# 474*473        =     224202 ,        2개의 곱 , n = 559
# 475*474        =     225150 ,        2개의 곱 , n = 560
# 476*475        =     226100 ,        2개의 곱 , n = 561
# 62*61*60       =     226920 ,        3개의 곱 , n = 562
#
# 477*476        =     227052 ,        2개의 곱 , n = 563
# 478*477        =     228006 ,        2개의 곱 , n = 564
# 479*478        =     228962 ,        2개의 곱 , n = 565
# 480*479        =     229920 ,        2개의 곱 , n = 566
# 481*480        =     230880 ,        2개의 곱 , n = 567
# 482*481        =     231842 ,        2개의 곱 , n = 568
# 483*482        =     232806 ,        2개의 곱 , n = 569
# 484*483        =     233772 ,        2개의 곱 , n = 570
# 485*484        =     234740 ,        2개의 곱 , n = 571
# 486*485        =     235710 ,        2개의 곱 , n = 572
# 487*486        =     236682 ,        2개의 곱 , n = 573
# 488*487        =     237656 ,        2개의 곱 , n = 574
# 63*62*61       =     238266 ,        3개의 곱 , n = 575
#
# 489*488        =     238632 ,        2개의 곱 , n = 576
# 490*489        =     239610 ,        2개의 곱 , n = 577
# 14*13*12*11*10 =     240240 ,        5개의 곱 , n = 578
#
# 491*490        =     240590 ,        2개의 곱 , n = 579
# 492*491        =     241572 ,        2개의 곱 , n = 580
# 493*492        =     242556 ,        2개의 곱 , n = 581
# 494*493        =     243542 ,        2개의 곱 , n = 582
# 495*494        =     244530 ,        2개의 곱 , n = 583
# 496*495        =     245520 ,        2개의 곱 , n = 584
# 497*496        =     246512 ,        2개의 곱 , n = 585
# 498*497        =     247506 ,        2개의 곱 , n = 586
# 499*498        =     248502 ,        2개의 곱 , n = 587
# 500*499        =     249500 ,        2개의 곱 , n = 588
# 64*63*62       =     249984 ,        3개의 곱 , n = 589
#
# 501*500        =     250500 ,        2개의 곱 , n = 590
# 502*501        =     251502 ,        2개의 곱 , n = 591
# 503*502        =     252506 ,        2개의 곱 , n = 592
# 504*503        =     253512 ,        2개의 곱 , n = 593
# 505*504        =     254520 ,        2개의 곱 , n = 594
# 24*23*22*21    =     255024 ,        4개의 곱 , n = 595
#
# 506*505        =     255530 ,        2개의 곱 , n = 596
# 507*506        =     256542 ,        2개의 곱 , n = 597
# 508*507        =     257556 ,        2개의 곱 , n = 598
# 509*508        =     258572 ,        2개의 곱 , n = 599
# 510*509        =     259590 ,        2개의 곱 , n = 600
# 511*510        =     260610 ,        2개의 곱 , n = 601
# 512*511        =     261632 ,        2개의 곱 , n = 602
# 65*64*63       =     262080 ,        3개의 곱 , n = 603
#
# 513*512        =     262656 ,        2개의 곱 , n = 604
# 514*513        =     263682 ,        2개의 곱 , n = 605
# 515*514        =     264710 ,        2개의 곱 , n = 606
# 516*515        =     265740 ,        2개의 곱 , n = 607
# 517*516        =     266772 ,        2개의 곱 , n = 608
# 518*517        =     267806 ,        2개의 곱 , n = 609
# 519*518        =     268842 ,        2개의 곱 , n = 610
# 520*519        =     269880 ,        2개의 곱 , n = 611
# 521*520        =     270920 ,        2개의 곱 , n = 612
# 522*521        =     271962 ,        2개의 곱 , n = 613
# 523*522        =     273006 ,        2개의 곱 , n = 614
# 524*523        =     274052 ,        2개의 곱 , n = 615
# 66*65*64       =     274560 ,        3개의 곱 , n = 616
#
# 525*524        =     275100 ,        2개의 곱 , n = 617
# 526*525        =     276150 ,        2개의 곱 , n = 618
# 527*526        =     277202 ,        2개의 곱 , n = 619
# 528*527        =     278256 ,        2개의 곱 , n = 620
# 529*528        =     279312 ,        2개의 곱 , n = 621
# 530*529        =     280370 ,        2개의 곱 , n = 622
# 531*530        =     281430 ,        2개의 곱 , n = 623
# 532*531        =     282492 ,        2개의 곱 , n = 624
# 533*532        =     283556 ,        2개의 곱 , n = 625
# 534*533        =     284622 ,        2개의 곱 , n = 626
# 535*534        =     285690 ,        2개의 곱 , n = 627
# 536*535        =     286760 ,        2개의 곱 , n = 628
# 67*66*65       =     287430 ,        3개의 곱 , n = 629
#
# 537*536        =     287832 ,        2개의 곱 , n = 630
# 538*537        =     288906 ,        2개의 곱 , n = 631
# 539*538        =     289982 ,        2개의 곱 , n = 632
# 540*539        =     291060 ,        2개의 곱 , n = 633
# 541*540        =     292140 ,        2개의 곱 , n = 634
# 542*541        =     293222 ,        2개의 곱 , n = 635
# 543*542        =     294306 ,        2개의 곱 , n = 636
# 544*543        =     295392 ,        2개의 곱 , n = 637
# 545*544        =     296480 ,        2개의 곱 , n = 638
# 546*545        =     297570 ,        2개의 곱 , n = 639
# 547*546        =     298662 ,        2개의 곱 , n = 640
# 548*547        =     299756 ,        2개의 곱 , n = 641
# 68*67*66       =     300696 ,        3개의 곱 , n = 642
#
# 549*548        =     300852 ,        2개의 곱 , n = 643
# 550*549        =     301950 ,        2개의 곱 , n = 644
# 551*550        =     303050 ,        2개의 곱 , n = 645
# 25*24*23*22    =     303600 ,        4개의 곱 , n = 646
#
# 552*551        =     304152 ,        2개의 곱 , n = 647
# 553*552        =     305256 ,        2개의 곱 , n = 648
# 554*553        =     306362 ,        2개의 곱 , n = 649
# 555*554        =     307470 ,        2개의 곱 , n = 650
# 556*555        =     308580 ,        2개의 곱 , n = 651
# 557*556        =     309692 ,        2개의 곱 , n = 652
# 558*557        =     310806 ,        2개의 곱 , n = 653
# 559*558        =     311922 ,        2개의 곱 , n = 654
# 560*559        =     313040 ,        2개의 곱 , n = 655
# 561*560        =     314160 ,        2개의 곱 , n = 656
# 69*68*67       =     314364 ,        3개의 곱 , n = 657
#
# 562*561        =     315282 ,        2개의 곱 , n = 658
# 563*562        =     316406 ,        2개의 곱 , n = 659
# 564*563        =     317532 ,        2개의 곱 , n = 660
# 565*564        =     318660 ,        2개의 곱 , n = 661
# 566*565        =     319790 ,        2개의 곱 , n = 662
# 567*566        =     320922 ,        2개의 곱 , n = 663
# 568*567        =     322056 ,        2개의 곱 , n = 664
# 569*568        =     323192 ,        2개의 곱 , n = 665
# 570*569        =     324330 ,        2개의 곱 , n = 666
# 571*570        =     325470 ,        2개의 곱 , n = 667
# 572*571        =     326612 ,        2개의 곱 , n = 668
# 573*572        =     327756 ,        2개의 곱 , n = 669
# 70*69*68       =     328440 ,        3개의 곱 , n = 670
#
# 574*573        =     328902 ,        2개의 곱 , n = 671
# 575*574        =     330050 ,        2개의 곱 , n = 672
# 576*575        =     331200 ,        2개의 곱 , n = 673
# 577*576        =     332352 ,        2개의 곱 , n = 674
# 11*10*9*8*7*6  =     332640 ,        6개의 곱 , n = 675
#
# 578*577        =     333506 ,        2개의 곱 , n = 676
# 579*578        =     334662 ,        2개의 곱 , n = 677
# 580*579        =     335820 ,        2개의 곱 , n = 678
# 581*580        =     336980 ,        2개의 곱 , n = 679
# 582*581        =     338142 ,        2개의 곱 , n = 680
# 583*582        =     339306 ,        2개의 곱 , n = 681
# 584*583        =     340472 ,        2개의 곱 , n = 682
# 585*584        =     341640 ,        2개의 곱 , n = 683
# 586*585        =     342810 ,        2개의 곱 , n = 684
# 71*70*69       =     342930 ,        3개의 곱 , n = 685
#
# 587*586        =     343982 ,        2개의 곱 , n = 686
# 588*587        =     345156 ,        2개의 곱 , n = 687
# 589*588        =     346332 ,        2개의 곱 , n = 688
# 590*589        =     347510 ,        2개의 곱 , n = 689
# 591*590        =     348690 ,        2개의 곱 , n = 690
# 592*591        =     349872 ,        2개의 곱 , n = 691
# 593*592        =     351056 ,        2개의 곱 , n = 692
# 594*593        =     352242 ,        2개의 곱 , n = 693
# 595*594        =     353430 ,        2개의 곱 , n = 694
# 596*595        =     354620 ,        2개의 곱 , n = 695
# 597*596        =     355812 ,        2개의 곱 , n = 696
# 598*597        =     357006 ,        2개의 곱 , n = 697
# 72*71*70       =     357840 ,        3개의 곱 , n = 698
#
# 599*598        =     358202 ,        2개의 곱 , n = 699
# 26*25*24*23    =     358800 ,        4개의 곱 , n = 700
#
# 600*599        =     359400 ,        2개의 곱 , n = 701
# 15*14*13*12*11 =     360360 ,        5개의 곱 , n = 702
#
# 601*600        =     360600 ,        2개의 곱 , n = 703
# 602*601        =     361802 ,        2개의 곱 , n = 704
# 9*8*7*6*5*4*3*2 =     362880 ,        8개의 곱 , n = 705
# 9*8*7*6*5*4*3*2*1 = 중복362880 ,        9개의 곱 , n = 705
#
# 603*602        =     363006 ,        2개의 곱 , n = 706
# 604*603        =     364212 ,        2개의 곱 , n = 707
# 605*604        =     365420 ,        2개의 곱 , n = 708
# 606*605        =     366630 ,        2개의 곱 , n = 709
# 607*606        =     367842 ,        2개의 곱 , n = 710
# 608*607        =     369056 ,        2개의 곱 , n = 711
# 609*608        =     370272 ,        2개의 곱 , n = 712
# 610*609        =     371490 ,        2개의 곱 , n = 713
# 611*610        =     372710 ,        2개의 곱 , n = 714
# 73*72*71       =     373176 ,        3개의 곱 , n = 715
#
# 612*611        =     373932 ,        2개의 곱 , n = 716
# 613*612        =     375156 ,        2개의 곱 , n = 717
# 614*613        =     376382 ,        2개의 곱 , n = 718
# 615*614        =     377610 ,        2개의 곱 , n = 719
# 616*615        =     378840 ,        2개의 곱 , n = 720
# 617*616        =     380072 ,        2개의 곱 , n = 721
# 618*617        =     381306 ,        2개의 곱 , n = 722
# 619*618        =     382542 ,        2개의 곱 , n = 723
# 620*619        =     383780 ,        2개의 곱 , n = 724
# 621*620        =     385020 ,        2개의 곱 , n = 725
# 622*621        =     386262 ,        2개의 곱 , n = 726
# 623*622        =     387506 ,        2개의 곱 , n = 727
# 624*623        =     388752 ,        2개의 곱 , n = 728
# 74*73*72       =     388944 ,        3개의 곱 , n = 729
#
# 625*624        =     390000 ,        2개의 곱 , n = 730
# 626*625        =     391250 ,        2개의 곱 , n = 731
# 627*626        =     392502 ,        2개의 곱 , n = 732
# 628*627        =     393756 ,        2개의 곱 , n = 733
# 629*628        =     395012 ,        2개의 곱 , n = 734
# 630*629        =     396270 ,        2개의 곱 , n = 735
# 631*630        =     397530 ,        2개의 곱 , n = 736
# 632*631        =     398792 ,        2개의 곱 , n = 737
# 633*632        =     400056 ,        2개의 곱 , n = 738
# 634*633        =     401322 ,        2개의 곱 , n = 739
# 635*634        =     402590 ,        2개의 곱 , n = 740
# 636*635        =     403860 ,        2개의 곱 , n = 741
# 637*636        =     405132 ,        2개의 곱 , n = 742
# 75*74*73       =     405150 ,        3개의 곱 , n = 743
#
# 638*637        =     406406 ,        2개의 곱 , n = 744
# 639*638        =     407682 ,        2개의 곱 , n = 745
# 640*639        =     408960 ,        2개의 곱 , n = 746
# 641*640        =     410240 ,        2개의 곱 , n = 747
# 642*641        =     411522 ,        2개의 곱 , n = 748
# 643*642        =     412806 ,        2개의 곱 , n = 749
# 644*643        =     414092 ,        2개의 곱 , n = 750
# 645*644        =     415380 ,        2개의 곱 , n = 751
# 646*645        =     416670 ,        2개의 곱 , n = 752
# 647*646        =     417962 ,        2개의 곱 , n = 753
# 648*647        =     419256 ,        2개의 곱 , n = 754
# 649*648        =     420552 ,        2개의 곱 , n = 755
# 27*26*25*24    =     421200 ,        4개의 곱 , n = 756
# 76*75*74       =     421800 ,        3개의 곱 , n = 757
#
# 650*649        =     421850 ,        2개의 곱 , n = 758
# 651*650        =     423150 ,        2개의 곱 , n = 759
# 652*651        =     424452 ,        2개의 곱 , n = 760
# 653*652        =     425756 ,        2개의 곱 , n = 761
# 654*653        =     427062 ,        2개의 곱 , n = 762
# 655*654        =     428370 ,        2개의 곱 , n = 763
# 656*655        =     429680 ,        2개의 곱 , n = 764
# 657*656        =     430992 ,        2개의 곱 , n = 765
# 658*657        =     432306 ,        2개의 곱 , n = 766
# 659*658        =     433622 ,        2개의 곱 , n = 767
# 660*659        =     434940 ,        2개의 곱 , n = 768
# 661*660        =     436260 ,        2개의 곱 , n = 769
# 662*661        =     437582 ,        2개의 곱 , n = 770
# 77*76*75       =     438900 ,        3개의 곱 , n = 771
#
# 663*662        =     438906 ,        2개의 곱 , n = 772
# 664*663        =     440232 ,        2개의 곱 , n = 773
# 665*664        =     441560 ,        2개의 곱 , n = 774
# 666*665        =     442890 ,        2개의 곱 , n = 775
# 667*666        =     444222 ,        2개의 곱 , n = 776
# 668*667        =     445556 ,        2개의 곱 , n = 777
# 669*668        =     446892 ,        2개의 곱 , n = 778
# 670*669        =     448230 ,        2개의 곱 , n = 779
# 671*670        =     449570 ,        2개의 곱 , n = 780
# 672*671        =     450912 ,        2개의 곱 , n = 781
# 673*672        =     452256 ,        2개의 곱 , n = 782
# 674*673        =     453602 ,        2개의 곱 , n = 783
# 675*674        =     454950 ,        2개의 곱 , n = 784
# 676*675        =     456300 ,        2개의 곱 , n = 785
# 78*77*76       =     456456 ,        3개의 곱 , n = 786
#
# 677*676        =     457652 ,        2개의 곱 , n = 787
# 678*677        =     459006 ,        2개의 곱 , n = 788
# 679*678        =     460362 ,        2개의 곱 , n = 789
# 680*679        =     461720 ,        2개의 곱 , n = 790
# 681*680        =     463080 ,        2개의 곱 , n = 791
# 682*681        =     464442 ,        2개의 곱 , n = 792
# 683*682        =     465806 ,        2개의 곱 , n = 793
# 684*683        =     467172 ,        2개의 곱 , n = 794
# 685*684        =     468540 ,        2개의 곱 , n = 795
# 686*685        =     469910 ,        2개의 곱 , n = 796
# 687*686        =     471282 ,        2개의 곱 , n = 797
# 688*687        =     472656 ,        2개의 곱 , n = 798
# 689*688        =     474032 ,        2개의 곱 , n = 799
# 79*78*77       =     474474 ,        3개의 곱 , n = 800
#
# 690*689        =     475410 ,        2개의 곱 , n = 801
# 691*690        =     476790 ,        2개의 곱 , n = 802
# 692*691        =     478172 ,        2개의 곱 , n = 803
# 693*692        =     479556 ,        2개의 곱 , n = 804
# 694*693        =     480942 ,        2개의 곱 , n = 805
# 695*694        =     482330 ,        2개의 곱 , n = 806
# 696*695        =     483720 ,        2개의 곱 , n = 807
# 697*696        =     485112 ,        2개의 곱 , n = 808
# 698*697        =     486506 ,        2개의 곱 , n = 809
# 699*698        =     487902 ,        2개의 곱 , n = 810
# 700*699        =     489300 ,        2개의 곱 , n = 811
# 701*700        =     490700 ,        2개의 곱 , n = 812
# 28*27*26*25    =     491400 ,        4개의 곱 , n = 813
#
# 702*701        =     492102 ,        2개의 곱 , n = 814
# 80*79*78       =     492960 ,        3개의 곱 , n = 815
#
# 703*702        =     493506 ,        2개의 곱 , n = 816
# 704*703        =     494912 ,        2개의 곱 , n = 817
# 705*704        =     496320 ,        2개의 곱 , n = 818
# 706*705        =     497730 ,        2개의 곱 , n = 819
# 707*706        =     499142 ,        2개의 곱 , n = 820
# 708*707        =     500556 ,        2개의 곱 , n = 821
# 709*708        =     501972 ,        2개의 곱 , n = 822
# 710*709        =     503390 ,        2개의 곱 , n = 823
# 711*710        =     504810 ,        2개의 곱 , n = 824
# 712*711        =     506232 ,        2개의 곱 , n = 825
# 713*712        =     507656 ,        2개의 곱 , n = 826
# 714*713        =     509082 ,        2개의 곱 , n = 827
# 715*714        =     510510 ,        2개의 곱 , n = 828
# 81*80*79       =     511920 ,        3개의 곱 , n = 829
#
# 716*715        =     511940 ,        2개의 곱 , n = 830
# 717*716        =     513372 ,        2개의 곱 , n = 831
# 718*717        =     514806 ,        2개의 곱 , n = 832
# 719*718        =     516242 ,        2개의 곱 , n = 833
# 720*719        =     517680 ,        2개의 곱 , n = 834
# 721*720        =     519120 ,        2개의 곱 , n = 835
# 722*721        =     520562 ,        2개의 곱 , n = 836
# 723*722        =     522006 ,        2개의 곱 , n = 837
# 724*723        =     523452 ,        2개의 곱 , n = 838
# 16*15*14*13*12 =     524160 ,        5개의 곱 , n = 839
#
# 725*724        =     524900 ,        2개의 곱 , n = 840
# 726*725        =     526350 ,        2개의 곱 , n = 841
# 727*726        =     527802 ,        2개의 곱 , n = 842
# 728*727        =     529256 ,        2개의 곱 , n = 843
# 729*728        =     530712 ,        2개의 곱 , n = 844
# 82*81*80       =     531360 ,        3개의 곱 , n = 845
#
# 730*729        =     532170 ,        2개의 곱 , n = 846
# 731*730        =     533630 ,        2개의 곱 , n = 847
# 732*731        =     535092 ,        2개의 곱 , n = 848
# 733*732        =     536556 ,        2개의 곱 , n = 849
# 734*733        =     538022 ,        2개의 곱 , n = 850
# 735*734        =     539490 ,        2개의 곱 , n = 851
# 736*735        =     540960 ,        2개의 곱 , n = 852
# 737*736        =     542432 ,        2개의 곱 , n = 853
# 738*737        =     543906 ,        2개의 곱 , n = 854
# 739*738        =     545382 ,        2개의 곱 , n = 855
# 740*739        =     546860 ,        2개의 곱 , n = 856
# 741*740        =     548340 ,        2개의 곱 , n = 857
# 742*741        =     549822 ,        2개의 곱 , n = 858
# 83*82*81       =     551286 ,        3개의 곱 , n = 859
#
# 743*742        =     551306 ,        2개의 곱 , n = 860
# 744*743        =     552792 ,        2개의 곱 , n = 861
# 745*744        =     554280 ,        2개의 곱 , n = 862
# 746*745        =     555770 ,        2개의 곱 , n = 863
# 747*746        =     557262 ,        2개의 곱 , n = 864
# 748*747        =     558756 ,        2개의 곱 , n = 865
# 749*748        =     560252 ,        2개의 곱 , n = 866
# 750*749        =     561750 ,        2개의 곱 , n = 867
# 751*750        =     563250 ,        2개의 곱 , n = 868
# 752*751        =     564752 ,        2개의 곱 , n = 869
# 753*752        =     566256 ,        2개의 곱 , n = 870
# 754*753        =     567762 ,        2개의 곱 , n = 871
# 755*754        =     569270 ,        2개의 곱 , n = 872
# 29*28*27*26    =     570024 ,        4개의 곱 , n = 873
#
# 756*755        =     570780 ,        2개의 곱 , n = 874
# 84*83*82       =     571704 ,        3개의 곱 , n = 875
#
# 757*756        =     572292 ,        2개의 곱 , n = 876
# 758*757        =     573806 ,        2개의 곱 , n = 877
# 759*758        =     575322 ,        2개의 곱 , n = 878
# 760*759        =     576840 ,        2개의 곱 , n = 879
# 761*760        =     578360 ,        2개의 곱 , n = 880
# 762*761        =     579882 ,        2개의 곱 , n = 881
# 763*762        =     581406 ,        2개의 곱 , n = 882
# 764*763        =     582932 ,        2개의 곱 , n = 883
# 765*764        =     584460 ,        2개의 곱 , n = 884
# 766*765        =     585990 ,        2개의 곱 , n = 885
# 767*766        =     587522 ,        2개의 곱 , n = 886
# 768*767        =     589056 ,        2개의 곱 , n = 887
# 769*768        =     590592 ,        2개의 곱 , n = 888
# 770*769        =     592130 ,        2개의 곱 , n = 889
# 85*84*83       =     592620 ,        3개의 곱 , n = 890
#
# 771*770        =     593670 ,        2개의 곱 , n = 891
# 772*771        =     595212 ,        2개의 곱 , n = 892
# 773*772        =     596756 ,        2개의 곱 , n = 893
# 774*773        =     598302 ,        2개의 곱 , n = 894
# 775*774        =     599850 ,        2개의 곱 , n = 895
# 776*775        =     601400 ,        2개의 곱 , n = 896
# 777*776        =     602952 ,        2개의 곱 , n = 897
# 778*777        =     604506 ,        2개의 곱 , n = 898
# 10*9*8*7*6*5*4 =     604800 ,        7개의 곱 , n = 899
#
# 779*778        =     606062 ,        2개의 곱 , n = 900
# 780*779        =     607620 ,        2개의 곱 , n = 901
# 781*780        =     609180 ,        2개의 곱 , n = 902
# 782*781        =     610742 ,        2개의 곱 , n = 903
# 783*782        =     612306 ,        2개의 곱 , n = 904
# 784*783        =     613872 ,        2개의 곱 , n = 905
# 86*85*84       =     614040 ,        3개의 곱 , n = 906
#
# 785*784        =     615440 ,        2개의 곱 , n = 907
# 786*785        =     617010 ,        2개의 곱 , n = 908
# 787*786        =     618582 ,        2개의 곱 , n = 909
# 788*787        =     620156 ,        2개의 곱 , n = 910
# 789*788        =     621732 ,        2개의 곱 , n = 911
# 790*789        =     623310 ,        2개의 곱 , n = 912
# 791*790        =     624890 ,        2개의 곱 , n = 913
# 792*791        =     626472 ,        2개의 곱 , n = 914
# 793*792        =     628056 ,        2개의 곱 , n = 915
# 794*793        =     629642 ,        2개의 곱 , n = 916
# 795*794        =     631230 ,        2개의 곱 , n = 917
# 796*795        =     632820 ,        2개의 곱 , n = 918
# 797*796        =     634412 ,        2개의 곱 , n = 919
# 87*86*85       =     635970 ,        3개의 곱 , n = 920
#
# 798*797        =     636006 ,        2개의 곱 , n = 921
# 799*798        =     637602 ,        2개의 곱 , n = 922
# 800*799        =     639200 ,        2개의 곱 , n = 923
# 801*800        =     640800 ,        2개의 곱 , n = 924
# 802*801        =     642402 ,        2개의 곱 , n = 925
# 803*802        =     644006 ,        2개의 곱 , n = 926
# 804*803        =     645612 ,        2개의 곱 , n = 927
# 805*804        =     647220 ,        2개의 곱 , n = 928
# 806*805        =     648830 ,        2개의 곱 , n = 929
# 807*806        =     650442 ,        2개의 곱 , n = 930
# 808*807        =     652056 ,        2개의 곱 , n = 931
# 809*808        =     653672 ,        2개의 곱 , n = 932
# 810*809        =     655290 ,        2개의 곱 , n = 933
# 811*810        =     656910 ,        2개의 곱 , n = 934
# 30*29*28*27    =     657720 ,        4개의 곱 , n = 935
# 88*87*86       =     658416 ,        3개의 곱 , n = 936
#
# 812*811        =     658532 ,        2개의 곱 , n = 937
# 813*812        =     660156 ,        2개의 곱 , n = 938
# 814*813        =     661782 ,        2개의 곱 , n = 939
# 815*814        =     663410 ,        2개의 곱 , n = 940
# 816*815        =     665040 ,        2개의 곱 , n = 941
# 12*11*10*9*8*7 =     665280 ,        6개의 곱 , n = 942
#
# 817*816        =     666672 ,        2개의 곱 , n = 943
# 818*817        =     668306 ,        2개의 곱 , n = 944
# 819*818        =     669942 ,        2개의 곱 , n = 945
# 820*819        =     671580 ,        2개의 곱 , n = 946
# 821*820        =     673220 ,        2개의 곱 , n = 947
# 822*821        =     674862 ,        2개의 곱 , n = 948
# 823*822        =     676506 ,        2개의 곱 , n = 949
# 824*823        =     678152 ,        2개의 곱 , n = 950
# 825*824        =     679800 ,        2개의 곱 , n = 951
# 89*88*87       =     681384 ,        3개의 곱 , n = 952
#
# 826*825        =     681450 ,        2개의 곱 , n = 953
# 827*826        =     683102 ,        2개의 곱 , n = 954
# 828*827        =     684756 ,        2개의 곱 , n = 955
# 829*828        =     686412 ,        2개의 곱 , n = 956
# 830*829        =     688070 ,        2개의 곱 , n = 957
# 831*830        =     689730 ,        2개의 곱 , n = 958
# 832*831        =     691392 ,        2개의 곱 , n = 959
# 833*832        =     693056 ,        2개의 곱 , n = 960
# 834*833        =     694722 ,        2개의 곱 , n = 961
# 835*834        =     696390 ,        2개의 곱 , n = 962
# 836*835        =     698060 ,        2개의 곱 , n = 963
# 837*836        =     699732 ,        2개의 곱 , n = 964
# 838*837        =     701406 ,        2개의 곱 , n = 965
# 839*838        =     703082 ,        2개의 곱 , n = 966
# 840*839        =     704760 ,        2개의 곱 , n = 967
# 90*89*88       =     704880 ,        3개의 곱 , n = 968
#
# 841*840        =     706440 ,        2개의 곱 , n = 969
# 842*841        =     708122 ,        2개의 곱 , n = 970
# 843*842        =     709806 ,        2개의 곱 , n = 971
# 844*843        =     711492 ,        2개의 곱 , n = 972
# 845*844        =     713180 ,        2개의 곱 , n = 973
# 846*845        =     714870 ,        2개의 곱 , n = 974
# 847*846        =     716562 ,        2개의 곱 , n = 975
# 848*847        =     718256 ,        2개의 곱 , n = 976
# 849*848        =     719952 ,        2개의 곱 , n = 977
# 850*849        =     721650 ,        2개의 곱 , n = 978
# 851*850        =     723350 ,        2개의 곱 , n = 979
# 852*851        =     725052 ,        2개의 곱 , n = 980
# 853*852        =     726756 ,        2개의 곱 , n = 981
# 854*853        =     728462 ,        2개의 곱 , n = 982
# 91*90*89       =     728910 ,        3개의 곱 , n = 983
#
# 855*854        =     730170 ,        2개의 곱 , n = 984
# 856*855        =     731880 ,        2개의 곱 , n = 985
# 857*856        =     733592 ,        2개의 곱 , n = 986
# 858*857        =     735306 ,        2개의 곱 , n = 987
# 859*858        =     737022 ,        2개의 곱 , n = 988
# 860*859        =     738740 ,        2개의 곱 , n = 989
# 861*860        =     740460 ,        2개의 곱 , n = 990
# 862*861        =     742182 ,        2개의 곱 , n = 991
# 17*16*15*14*13 =     742560 ,        5개의 곱 , n = 992
#
# 863*862        =     743906 ,        2개의 곱 , n = 993
# 864*863        =     745632 ,        2개의 곱 , n = 994
# 865*864        =     747360 ,        2개의 곱 , n = 995
# 866*865        =     749090 ,        2개의 곱 , n = 996
# 867*866        =     750822 ,        2개의 곱 , n = 997
# 868*867        =     752556 ,        2개의 곱 , n = 998
# 92*91*90       =     753480 ,        3개의 곱 , n = 999
#
# 869*868        =     754292 ,        2개의 곱 , n = 1000
