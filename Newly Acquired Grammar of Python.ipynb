# %%
# List Comprehension
# 대체로 표현식이 2개를 넘지 않도록 해야 깔끔함
lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]
lc2 = []
for n in range(1, 10+1):
    if n%2 == 1:
        lc2.append(n*2)
print(lc1 == lc2)

# Dictionary Comprehension
#a = {key: value for key, value in original.items()}
# Out:
# True

# %%
# enumerate
enum_arr1 = ['a1', 'a2', 'a3']
for i, v in enumerate(enum_arr1):
    print(i, v)
for i in range(len(enum_arr1)):
    print(i, enum_arr1[i])
# Out:
# 0 a1
# 1 a2
# 2 a3
# 0 a1
# 1 a2
# 2 a3

# %%
# divmod(int, int)
divmod_result, divmod_modulo = divmod(5,3)
print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))
# Out:
# 5//3 = 1 , 5%3 == 2

# %%
# f-string (formated string litreal)
idx, fruit = 1, 'Apple'
print(f'{idx+1}: {fruit}')
print('{}: {}'.format(idx+1, fruit))
# Out:
# 2: Apple
# 2: Apple

# %%
# locals : 로컬에 선언된 모든 변수를 dict 형태로 가져온다
import pprint
pprint.pprint(locals())
# Out:
# {'In': ['',
#         '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'lc1 == lc2',
#         '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         '(lc1 == lc2) == True',
#         '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'print(lc1 == lc2)',
#         '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'print(lc1 == lc2)\n'
#         '\n'
#         '# Dictionary Comprehension\n'
#         '#a = {key: value for key, value in original.items()}',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1)):\n'
#         '    print(i, enum_arr1[i])',
#         '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1)):\n'
#         '    print(i, enum_arr1[i])',
#         '# divmod(int, int)\n'
#         'divmod_result, divmod_modulo = divmod(5,3)\n'
#         "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmode_modulo))",
#         '# divmod(int, int)\n'
#         'divmod_result, divmod_modulo = divmod(5,3)\n'
#         "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#         '# divmod(int, int)\n'
#         'divmod_result, divmod_modulo = divmod(5,3)\n'
#         "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#         '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}')",
#         '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}')== print('{}: {}'.format(idx+1, fruit))",
#         '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}') == print('{}: {}'.format(idx+1, fruit))",
#         '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}')\n"
#         "print('{}: {}'.format(idx+1, fruit))",
#         '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}')\n"
#         "print('{}: {}'.format(idx+1, fruit))",
#         'import pprint\npprint.pprint(locals())'],
#  'Out': {1: True, 2: True, 15: True, 16: True},
#  '_': True,
#  '_1': True,
#  '_15': True,
#  '_16': True,
#  '_2': True,
#  '__': True,
#  '___': True,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/Users/Yoonki/git'],
#  '_i': '# f-string (formated string litreal)\n'
#        "idx, fruit = 1, 'Apple'\n"
#        "print(f'{idx+1}: {fruit}')\n"
#        "print('{}: {}'.format(idx+1, fruit))",
#  '_i1': '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'lc1 == lc2',
#  '_i10': '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(len(enum_arr1)):\n'
#          '    print(i, enum_arr1[i])',
#  '_i11': '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmode_modulo))",
#  '_i12': '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#  '_i13': '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#  '_i14': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')",
#  '_i15': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')== print('{}: {}'.format(idx+1, fruit))",
#  '_i16': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}') == print('{}: {}'.format(idx+1, fruit))",
#  '_i17': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')\n"
#          "print('{}: {}'.format(idx+1, fruit))",
#  '_i18': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')\n"
#          "print('{}: {}'.format(idx+1, fruit))",
#  '_i19': 'import pprint\npprint.pprint(locals())',
#  '_i2': '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         '(lc1 == lc2) == True',
#  '_i3': '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'print(lc1 == lc2)',
#  '_i4': '# List Comprehension\n'
#         'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#         'lc2 = []\n'
#         'for n in range(1, 10+1):\n'
#         '    if n%2 == 1:\n'
#         '        lc2.append(n*2)\n'
#         'print(lc1 == lc2)\n'
#         '\n'
#         '# Dictionary Comprehension\n'
#         '#a = {key: value for key, value in original.items()}',
#  '_i5': '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)',
#  '_i6': '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#  '_i7': '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#  '_i8': '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1):\n'
#         '    print(i, enum_arr1[i])',
#  '_i9': '# enumerate\n'
#         "enum_arr1 = ['a1', 'a2', 'a3']\n"
#         'for i, v in enumerate(enum_arr1):\n'
#         '    print(i, v)\n'
#         'for i in range(len(enum_arr1)):\n'
#         '    print(i, enum_arr1[i])',
#  '_ih': ['',
#          '# List Comprehension\n'
#          'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#          'lc2 = []\n'
#          'for n in range(1, 10+1):\n'
#          '    if n%2 == 1:\n'
#          '        lc2.append(n*2)\n'
#          'lc1 == lc2',
#          '# List Comprehension\n'
#          'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#          'lc2 = []\n'
#          'for n in range(1, 10+1):\n'
#          '    if n%2 == 1:\n'
#          '        lc2.append(n*2)\n'
#          '(lc1 == lc2) == True',
#          '# List Comprehension\n'
#          'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#          'lc2 = []\n'
#          'for n in range(1, 10+1):\n'
#          '    if n%2 == 1:\n'
#          '        lc2.append(n*2)\n'
#          'print(lc1 == lc2)',
#          '# List Comprehension\n'
#          'lc1 = [n * 2 for n in range(1, 10+1) if n%2 == 1]\n'
#          'lc2 = []\n'
#          'for n in range(1, 10+1):\n'
#          '    if n%2 == 1:\n'
#          '        lc2.append(n*2)\n'
#          'print(lc1 == lc2)\n'
#          '\n'
#          '# Dictionary Comprehension\n'
#          '#a = {key: value for key, value in original.items()}',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(enum_arr1):\n'
#          '    print(i, enum_arr1[i])',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(len(enum_arr1):\n'
#          '    print(i, enum_arr1[i])',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(len(enum_arr1):\n'
#          '    print(i, enum_arr1[i])',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(len(enum_arr1)):\n'
#          '    print(i, enum_arr1[i])',
#          '# enumerate\n'
#          "enum_arr1 = ['a1', 'a2', 'a3']\n"
#          'for i, v in enumerate(enum_arr1):\n'
#          '    print(i, v)\n'
#          'for i in range(len(enum_arr1)):\n'
#          '    print(i, enum_arr1[i])',
#          '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmode_modulo))",
#          '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#          '# divmod(int, int)\n'
#          'divmod_result, divmod_modulo = divmod(5,3)\n'
#          "print('5//3 = {} , 5%3 == {}'.format(divmod_result, divmod_modulo))",
#          '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')",
#          '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')== print('{}: {}'.format(idx+1, fruit))",
#          '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}') == print('{}: {}'.format(idx+1, fruit))",
#          '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')\n"
#          "print('{}: {}'.format(idx+1, fruit))",
#          '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}')\n"
#          "print('{}: {}'.format(idx+1, fruit))",
#          'import pprint\npprint.pprint(locals())'],
#  '_ii': '# f-string (formated string litreal)\n'
#         "idx, fruit = 1, 'Apple'\n"
#         "print(f'{idx+1}: {fruit}')\n"
#         "print('{}: {}'.format(idx+1, fruit))",
#  '_iii': '# f-string (formated string litreal)\n'
#          "idx, fruit = 1, 'Apple'\n"
#          "print(f'{idx+1}: {fruit}') == print('{}: {}'.format(idx+1, fruit))",
#  '_oh': {1: True, 2: True, 15: True, 16: True},
#  'divmod_modulo': 2,
#  'divmod_result': 1,
#  'enum_arr1': ['a1', 'a2', 'a3'],
#  'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x7fe2486a6c40>,
#  'fruit': 'Apple',
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe248699100>>,
#  'i': 2,
#  'idx': 1,
#  'lc1': [2, 6, 10, 14, 18],
#  'lc2': [2, 6, 10, 14, 18],
#  'n': 10,
#  'pprint': <module 'pprint' from '/Users/Yoonki/opt/anaconda3/lib/python3.8/pprint.py'>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x7fe2486a6c40>,
#  'v': 'a3'}
